# %%
import json
import pandas as pd
import argparse
from typing import List
import os

# %%
# 소수 두째자리까지 round
def rounder(num):
    return round(num, 2)

def post_process_metric(x, not_hundred_metrics):
    keys = x.keys()
    for k in keys:
        if max([hm in k for hm in not_hundred_metrics]):
            x[k] = x[k] * 100
        x[k] = rounder(x[k])
    return x

# %%
def parse_logfile(log_folder_name):
    if not log_folder_name.endswith('.json'):
        latest_checkpoint = sorted([d for d in os.listdir(path) if 'checkpoint' in d and not 'ipynb' in d],
                                    key=lambda x : int(x.split('-')[1]))[-1]
        file = os.path.join(log_folder_name, latest_checkpoint, 'trainer_state.json')
    else:
        file = log_folder_name
    logs = pd.read_json(file).log_history
    
    # aggregate logs
    eval_seen = [l for l in logs if 'eval_seen_ppl' in l.keys()]
    eval_unseen = [l for l in logs if 'eval_unseen_ppl' in l.keys()]
    test_seen = [l for l in logs if 'test_seen_ppl' in l.keys()]
    test_unseen = [l for l in logs if 'test_unseen_ppl' in l.keys()]
    
    assert len(eval_seen) == len(eval_unseen) == len(test_seen) == len(test_unseen)
    for i in range(len(eval_seen)):
        eval_seen[i].update(eval_unseen[i])
        eval_seen[i].update(test_seen[i])
        eval_seen[i].update(test_unseen[i])
    
    log_pd = pd.DataFrame(eval_seen)
    keys = log_pd.keys()
    
    metrics = sorted([s for s in set([k.split('seen')[-1].strip('_') for k in keys])
                      if not max([i in s for i in ['num', 'runtime', 'second', 'epoch', 'step']])])
    not_hundred_metrics = [m for m in metrics if not max([i in m for i in ['know_acc', 'loss', 'ppl']])]
    
    new_keys = ['epoch', 'step']
    for m in metrics:
        new_keys.append('eval_seen_'+m)
        new_keys.append('eval_unseen_'+m)
        new_keys.append('test_seen_'+m)
        new_keys.append('test_unseen_'+m)
        
    log_pd_processed = log_pd.apply(lambda x : post_process_metric(x, not_hundred_metrics), axis=1)
    return log_pd_processed[new_keys]   
    # return log_pd

# %%
a = parse_logfile('output/wowtest3/trainer_state.json')

# %%
a
# Out:
#     epoch     step  eval_seen_BLEU1  eval_unseen_BLEU1  test_seen_BLEU1  \
# 0     1.0   2303.0             5.85               5.61             5.57
# 1     2.0   4606.0             7.85               8.25             7.92
# 2     3.0   6909.0             9.56               9.05             9.37
# 3     4.0   9212.0            10.66              10.09            10.39
# 4     5.0  11515.0            11.16              10.31            10.98
# 5     6.0  13818.0            11.14              10.12            11.04
# 6     7.0  16121.0            12.02              10.79            11.72
# 7     8.0  18424.0            12.01              10.14            11.54
# 8     9.0  20727.0            12.62              11.04            12.78
# 9    10.0  23030.0            12.92              10.86            12.39
# 10   11.0  25333.0            12.55              10.85            12.44
# 11   12.0  27636.0            13.00              11.17            12.96
# 12   13.0  29939.0            13.14              11.20            13.01
#
#     test_unseen_BLEU1  eval_seen_BLEU2  eval_unseen_BLEU2  test_seen_BLEU2  \
# 0                5.63             1.29               1.14             1.19
# 1                7.02             1.96               1.90             1.95
# 2                8.43             2.67               2.26             2.57
# 3                9.35             3.02               2.55             2.86
# 4                9.53             3.52               2.72             3.36
# 5                9.32             3.40               2.55             3.40
# 6               10.02             3.99               2.89             3.89
# 7                9.40             4.09               2.67             3.92
# 8               10.85             4.50               3.11             4.54
# 9               10.27             4.65               2.98             4.43
# 10              10.15             4.56               3.00             4.57
# 11              10.48             4.92               3.02             4.88
# 12              10.77             4.93               3.15             4.93
#
#     test_unseen_BLEU2  ...  test_seen_rougeL  test_unseen_rougeL  \
# 0                1.18  ...              8.39                8.49
# 1                1.74  ...             10.77                9.67
# 2                2.19  ...             12.38               11.01
# 3                2.16  ...             13.61               11.73
# 4                2.32  ...             13.55               11.52
# 5                2.20  ...             14.52               12.05
# 6                2.46  ...             14.83               12.24
# 7                2.32  ...             14.91               11.94
# 8                2.77  ...             15.65               12.79
# 9                2.53  ...             15.16               12.36
# 10               2.52  ...             15.42               12.29
# 11               2.86  ...             15.79               12.60
# 12               2.92  ...             15.91               12.95
#
#     eval_seen_token_loss  eval_unseen_token_loss  test_seen_token_loss  \
# 0                   5.87                    6.10                  5.90
# 1                   5.42                    5.77                  5.46
# 2                   5.14                    5.59                  5.19
# 3                   4.94                    5.47                  5.00
# 4                   4.81                    5.40                  4.87
# 5                   4.72                    5.39                  4.78
# 6                   4.64                    5.38                  4.70
# 7                   4.58                    5.35                  4.64
# 8                   4.52                    5.32                  4.58
# 9                   4.52                    5.37                  4.59
# 10                  4.48                    5.38                  4.55
# 11                  4.48                    5.37                  4.54
# 12                  4.47                    5.39                  4.54
#
#     test_unseen_token_loss  eval_seen_total_loss  eval_unseen_total_loss  \
# 0                     6.16                  9.75                   11.12
# 1                     5.88                  9.21                   10.87
# 2                     5.72                  8.95                   10.85
# 3                     5.62                  8.78                   10.83
# 4                     5.55                  8.80                   10.95
# 5                     5.53                  8.89                   11.34
# 6                     5.53                  9.01                   11.77
# 7                     5.53                  9.06                   11.87
# 8                     5.47                  9.05                   11.85
# 9                     5.54                  9.39                   12.45
# 10                    5.53                  9.42                   12.63
# 11                    5.52                  9.59                   12.68
# 12                    5.54                  9.69                   12.85
#
#     test_seen_total_loss  test_unseen_total_loss
# 0                   9.90                   11.01
# 1                   9.40                   11.06
# 2                   9.15                   11.04
# 3                   9.00                   11.13
# 4                   9.04                   11.27
# 5                   9.14                   11.59
# 6                   9.31                   12.05
# 7                   9.36                   12.26
# 8                   9.36                   12.12
# 9                   9.75                   12.77
# 10                  9.76                   12.84
# 11                  9.91                   12.87
# 12                 10.02                   13.01
#
# [13 rows x 62 columns]

# %%
def write_folder_tocsv(write_file_name,
                       log_file_names : List,
                       ):
    for log_file_name in log_file_names:
        parsed_log = parse_logfile(log_file_name)
        
        # write file as csv
        write_csv_file_name = write_file_name+'.csv'
        parsed_log.to_csv(write_csv_file_name, mode='a')
        with open(write_csv_file_name, 'a') as f:
            f.write(log_file_name)
            f.write('\n\n')

# %%
def get_log_file_names(log_folder):
    log_file_names = [os.path.join(log_folder,log_file)
                      for log_file in os.listdir(log_folder)]
    return log_file_names

# %%
path = 'output/wowtest3'

# %%
latest_checkpoint = sorted([d for d in os.listdir(path) if 'checkpoint' in d], key=lambda x : int(x.split('-')[1]))[-1]

# %%
file = os.path.join(path, latest_checkpoint, 'trainer_state.json')

# %%
file = 'output/wowtest3/trainer_state.json'

# %%
a = pd.read_json(file).log_history

# %%
eval_seen = [aa for aa in a if 'eval_seen_ppl' in aa.keys()]
eval_unseen = [aa for aa in a if 'eval_unseen_ppl' in aa.keys()]
test_seen = [aa for aa in a if 'test_seen_ppl' in aa.keys()]
test_unseen = [aa for aa in a if 'test_unseen_ppl' in aa.keys()]

# %%
assert len(eval_seen) == len(eval_unseen) == len(test_seen) == len(test_unseen)

# %%
for i in range(len(eval_seen)):
    eval_seen[i].update(eval_unseen[i])
    eval_seen[i].update(test_seen[i])
    eval_seen[i].update(test_unseen[i])

# %%
d = pd.DataFrame(eval_seen)

# %%
keys = pd.DataFrame(eval_seen).keys()

# %%
metrics = sorted([s for s in set([k.split('seen')[-1].strip('_') for k in keys]) if not max([i in s for i in ['num', 'runtime', 'second', 'epoch', 'step']])])

# %%
metrics
# Out:
# ['BLEU1',
#  'BLEU2',
#  'BLEU3',
#  'BLEU4',
#  'Distinct-1',
#  'Distinct-2',
#  'F1',
#  'know_acc',
#  'knowledge_loss',
#  'ppl',
#  'rouge1',
#  'rouge2',
#  'rougeL',
#  'token_loss',
#  'total_loss']

# %%
not_hundred_metrics = [m for m in metrics if not max([i in m for i in ['know_acc', 'loss', 'ppl']])]

# %%
not_hundred_metrics
# Out:
# ['BLEU1',
#  'BLEU2',
#  'BLEU3',
#  'BLEU4',
#  'Distinct-1',
#  'Distinct-2',
#  'F1',
#  'rouge1',
#  'rouge2',
#  'rougeL']

# %%
d.apply(lambda x : )
# Out:
#     epoch  eval_seen_BLEU1  eval_seen_BLEU2  eval_seen_BLEU3  eval_seen_BLEU4  \
# 0     1.0         0.058510         0.012894         0.001982         0.000722
# 1     2.0         0.078471         0.019601         0.003888         0.001077
# 2     3.0         0.095602         0.026743         0.006384         0.001681
# 3     4.0         0.106576         0.030195         0.007743         0.002867
# 4     5.0         0.111576         0.035153         0.010178         0.003580
# 5     6.0         0.111393         0.033960         0.009280         0.003222
# 6     7.0         0.120231         0.039894         0.012193         0.005344
# 7     8.0         0.120127         0.040927         0.012756         0.005785
# 8     9.0         0.126193         0.044992         0.015258         0.007090
# 9    10.0         0.129229         0.046544         0.015429         0.007091
# 10   11.0         0.125470         0.045596         0.016496         0.007863
# 11   12.0         0.130016         0.049173         0.018261         0.008411
# 12   13.0         0.131383         0.049296         0.018434         0.009232
#
#     eval_seen_Distinct-1  eval_seen_Distinct-2  eval_seen_F1  \
# 0               0.001195              0.004463      0.094001
# 1               0.003541              0.017700      0.117044
# 2               0.005833              0.033122      0.137919
# 3               0.009856              0.054993      0.153579
# 4               0.012999              0.071559      0.151464
# 5               0.020326              0.108535      0.161270
# 6               0.024203              0.130281      0.167913
# 7               0.028507              0.152181      0.169608
# 8               0.030407              0.155902      0.172531
# 9               0.035082              0.173668      0.174417
# 10              0.039726              0.197031      0.172876
# 11              0.042578              0.206655      0.175754
# 12              0.047493              0.222134      0.179372
#
#     eval_seen_know_acc  eval_seen_knowledge_loss  ...  test_unseen_rouge1  \
# 0            25.539477                  3.882978  ...            0.090370
# 1            27.011932                  3.788660  ...            0.104146
# 2            27.113481                  3.810125  ...            0.119839
# 3            27.189642                  3.840566  ...            0.130343
# 4            26.732673                  3.987263  ...            0.128677
# 5            26.199543                  4.169706  ...            0.133620
# 6            25.818736                  4.371843  ...            0.136948
# 7            25.260218                  4.475227  ...            0.132672
# 8            25.260218                  4.531729  ...            0.143993
# 9            24.727088                  4.870489  ...            0.137606
# 10           24.676314                  4.940875  ...            0.137540
# 11           23.635440                  5.108103  ...            0.140970
# 12           23.889312                  5.210962  ...            0.145504
#
#     test_unseen_rouge2  test_unseen_rougeL  test_unseen_runtime  \
# 0             0.012079            0.084882             714.8713
# 1             0.017117            0.096719             734.1567
# 2             0.020590            0.110090             725.4196
# 3             0.019265            0.117314             705.4067
# 4             0.019991            0.115154             718.6471
# 5             0.019927            0.120454             688.6639
# 6             0.021217            0.122412             703.5591
# 7             0.021628            0.119412             684.9259
# 8             0.023550            0.127861             701.4569
# 9             0.021793            0.123608             724.5852
# 10            0.021529            0.122889             700.5157
# 11            0.024655            0.126004             704.3580
# 12            0.025532            0.129451             696.3415
#
#     test_unseen_samples_per_second  test_unseen_steps_per_second  \
# 0                            1.354                         0.677
# 1                            1.319                         0.659
# 2                            1.334                         0.667
# 3                            1.372                         0.686
# 4                            1.347                         0.673
# 5                            1.406                         0.703
# 6                            1.376                         0.688
# 7                            1.413                         0.707
# 8                            1.380                         0.690
# 9                            1.336                         0.668
# 10                           1.382                         0.691
# 11                           1.374                         0.687
# 12                           1.390                         0.695
#
#     test_unseen_token_loss  test_unseen_total_episode_num  \
# 0                 6.158024                            968
# 1                 5.878667                            968
# 2                 5.715868                            968
# 3                 5.617607                            968
# 4                 5.549252                            968
# 5                 5.529822                            968
# 6                 5.534378                            968
# 7                 5.526098                            968
# 8                 5.467641                            968
# 9                 5.538153                            968
# 10                5.526578                            968
# 11                5.521423                            968
# 12                5.541563                            968
#
#     test_unseen_total_loss  test_unseen_total_sentence_num
# 0                11.013030                            3922
# 1                11.056437                            3922
# 2                11.039643                            3922
# 3                11.125307                            3922
# 4                11.266858                            3922
# 5                11.594268                            3922
# 6                12.051908                            3922
# 7                12.260585                            3922
# 8                12.122010                            3922
# 9                12.772947                            3922
# 10               12.836178                            3922
# 11               12.870567                            3922
# 12               13.013042                            3922
#
# [13 rows x 82 columns]

# %%
def post_process_metric(x, not_hundred_metrics):
    keys = x.keys()
    for k in keys:
        if max([hm in k for hm in not_hundred_metrics]):
            x[k] = x[k] * 100
        x[k] = rounder(x[k])
    return x

# %%
d.apply(lambda x : post_process_metric(x, not_hundred_metrics), axis=1)
# Out:
#     epoch  eval_seen_BLEU1  eval_seen_BLEU2  eval_seen_BLEU3  eval_seen_BLEU4  \
# 0     1.0             5.85             1.29             0.20             0.07
# 1     2.0             7.85             1.96             0.39             0.11
# 2     3.0             9.56             2.67             0.64             0.17
# 3     4.0            10.66             3.02             0.77             0.29
# 4     5.0            11.16             3.52             1.02             0.36
# 5     6.0            11.14             3.40             0.93             0.32
# 6     7.0            12.02             3.99             1.22             0.53
# 7     8.0            12.01             4.09             1.28             0.58
# 8     9.0            12.62             4.50             1.53             0.71
# 9    10.0            12.92             4.65             1.54             0.71
# 10   11.0            12.55             4.56             1.65             0.79
# 11   12.0            13.00             4.92             1.83             0.84
# 12   13.0            13.14             4.93             1.84             0.92
#
#     eval_seen_Distinct-1  eval_seen_Distinct-2  eval_seen_F1  \
# 0                   0.12                  0.45          9.40
# 1                   0.35                  1.77         11.70
# 2                   0.58                  3.31         13.79
# 3                   0.99                  5.50         15.36
# 4                   1.30                  7.16         15.15
# 5                   2.03                 10.85         16.13
# 6                   2.42                 13.03         16.79
# 7                   2.85                 15.22         16.96
# 8                   3.04                 15.59         17.25
# 9                   3.51                 17.37         17.44
# 10                  3.97                 19.70         17.29
# 11                  4.26                 20.67         17.58
# 12                  4.75                 22.21         17.94
#
#     eval_seen_know_acc  eval_seen_knowledge_loss  ...  test_unseen_rouge1  \
# 0                25.54                      3.88  ...                9.04
# 1                27.01                      3.79  ...               10.41
# 2                27.11                      3.81  ...               11.98
# 3                27.19                      3.84  ...               13.03
# 4                26.73                      3.99  ...               12.87
# 5                26.20                      4.17  ...               13.36
# 6                25.82                      4.37  ...               13.69
# 7                25.26                      4.48  ...               13.27
# 8                25.26                      4.53  ...               14.40
# 9                24.73                      4.87  ...               13.76
# 10               24.68                      4.94  ...               13.75
# 11               23.64                      5.11  ...               14.10
# 12               23.89                      5.21  ...               14.55
#
#     test_unseen_rouge2  test_unseen_rougeL  test_unseen_runtime  \
# 0                 1.21                8.49               714.87
# 1                 1.71                9.67               734.16
# 2                 2.06               11.01               725.42
# 3                 1.93               11.73               705.41
# 4                 2.00               11.52               718.65
# 5                 1.99               12.05               688.66
# 6                 2.12               12.24               703.56
# 7                 2.16               11.94               684.93
# 8                 2.35               12.79               701.46
# 9                 2.18               12.36               724.59
# 10                2.15               12.29               700.52
# 11                2.47               12.60               704.36
# 12                2.55               12.95               696.34
#
#     test_unseen_samples_per_second  test_unseen_steps_per_second  \
# 0                             1.35                          0.68
# 1                             1.32                          0.66
# 2                             1.33                          0.67
# 3                             1.37                          0.69
# 4                             1.35                          0.67
# 5                             1.41                          0.70
# 6                             1.38                          0.69
# 7                             1.41                          0.71
# 8                             1.38                          0.69
# 9                             1.34                          0.67
# 10                            1.38                          0.69
# 11                            1.37                          0.69
# 12                            1.39                          0.70
#
#     test_unseen_token_loss  test_unseen_total_episode_num  \
# 0                     6.16                          968.0
# 1                     5.88                          968.0
# 2                     5.72                          968.0
# 3                     5.62                          968.0
# 4                     5.55                          968.0
# 5                     5.53                          968.0
# 6                     5.53                          968.0
# 7                     5.53                          968.0
# 8                     5.47                          968.0
# 9                     5.54                          968.0
# 10                    5.53                          968.0
# 11                    5.52                          968.0
# 12                    5.54                          968.0
#
#     test_unseen_total_loss  test_unseen_total_sentence_num
# 0                    11.01                          3922.0
# 1                    11.06                          3922.0
# 2                    11.04                          3922.0
# 3                    11.13                          3922.0
# 4                    11.27                          3922.0
# 5                    11.59                          3922.0
# 6                    12.05                          3922.0
# 7                    12.26                          3922.0
# 8                    12.12                          3922.0
# 9                    12.77                          3922.0
# 10                   12.84                          3922.0
# 11                   12.87                          3922.0
# 12                   13.01                          3922.0
#
# [13 rows x 82 columns]

# %%
rounder

# %%
new_keys = ['epoch', 'step']
for m in metrics:
    new_keys.append('eval_seen_'+m)
    new_keys.append('eval_unseen_'+m)
    new_keys.append('test_seen_'+m)
    new_keys.append('test_unseen_'+m)

# %%
d[new_keys]['eval_seen_ppl']
# Out:
# 0     352.583104
# 1     225.446893
# 2     170.018567
# 3     139.856059
# 4     122.500312
# 5     112.119942
# 6     103.284017
# 7      97.636196
# 8      91.913577
# 9      91.955135
# 10     88.348304
# 11     88.151702
# 12     87.734454
# Name: eval_seen_ppl, dtype: float64
